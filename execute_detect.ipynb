# %% [markdown]
# # *<font face =微軟黑體 color = aqua>Detect</font>*

# %%
import torch

print(torch.cuda.is_available()) 
print(torch.version.cuda)
# Out:
# True
# 11.8

# %%
# PYTORCH_CUDA_ALLOC_CONF 來減少記憶體碎片。這樣可以讓 PyTorch 的顯存管理更有效率
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %% [markdown]
# ## *<font face =微軟黑體 color = aqua>detect.py</font>*

# %%
# !python detect.py --source C:/Users/PZJ/Desktop/yolov9/test/test --img 640 --device 0 --weights runs/train/gelan-c9/weights/best_striped.pt --name gelan_c_c_640_detect
# Out:
# detect: weights=['runs/train/gelan-c9/weights/best_striped.pt'], source=C:/Users/PZJ/Desktop/yolov9/test/test, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=gelan_c_c_640_detect, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO  2024-11-10 Python-3.8.20 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
#
# ...

# %% [markdown]
# ## *<font face =微軟黑體 color = aqua>detect_dual.py</font>*

# %%
# !python detect_dual.py --source C:/Users/PZJ/Desktop/yolov9/test/test --img 640 --device 0 --weights runs/train/yolov9-c7/weights/best.pt --name yolov9_c_640_detect
# Out:
# detect_dual: weights=['runs/train/yolov9-c7/weights/best.pt'], source=C:/Users/PZJ/Desktop/yolov9/test/test, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=yolov9_c_640_detect, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO  2024-11-10 Python-3.8.20 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
#
# ...
